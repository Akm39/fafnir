# %%
from data import data_saver,data_loader
import datetime as dt

# %%
saver=data_saver('2024-01-01') #Make sure the folder you're referencing exists in the data folder

# %%
saver.fetch_data() #Fetches yfinance Data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
print(saver.missing_data()) #Display's missing data 
#- look into each of the missing values, if nothing can be done, 
# leave it and it'll automatically be filtered out
# Out:
# Ticker
# CEG     263
# KVUE    587
# VLTO    692
# PXD     965
# WRK     965
# GEHC    492
# dtype: int64

# %%
saver.dump_data() #Takes so long because covariance matrixes and betas are fully precomputed continuously and stored in the data.pkl object
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
loader=data_loader('2024-01-01') #Pickle used cuz its faster to load serialized data than anything else

# %%
#loader.set_cutoff(dt.datetime(2024,3,31)) #option to change the cutoff date between training & testing datasets

# %%
loader.sector_list()
# Out:
# ['Automobiles & Components',
#  'Banks',
#  'Capital Goods',
#  'Commercial & Professional Services',
#  'Consumer Discretionary Distribution & Retail',
#  'Consumer Durables & Apparel',
#  'Consumer Services',
#  'Consumer Staples Distribution & Retail',
#  'Energy',
#  'Equity Real Estate Investment Trusts (REITs)',
#  'Financial Services',
#  'Food, Beverage & Tobacco',
#  'Health Care Equipment & Services',
#  'Household & Personal Products',
#  'Insurance',
#  'Materials',
#  'Media & Entertainment',
#  'Pharmaceuticals, Biotechnology & Life Sciences',
#  'Real Estate Management & Development',
#  'Semiconductors & Semiconductor Equipment',
#  'Software & Services',
#  'Technology Hardware & Equipment',
#  'Telecommunication Services',
#  'Transportation',
#  'Utilities']

# %%
loader.load_price(sector='Consumer Services',tnt='train') #can load just specific parts of dataset, or all of it
# Out:
# Ticker             MCD        CCL        CZR         MAR       NCLH  \
# Date
# 2021-01-04  193.066162  20.379999  71.599998  121.776741  23.730000
# 2021-01-05  194.223389  20.600000  74.769997  123.065063  24.240000
# 2021-01-06  193.782547  20.400000  76.239998  126.285889  24.330000
# 2021-01-07  194.682587  20.740000  78.059998  127.222847  24.660000
# 2021-01-08  198.255142  20.469999  78.800003  126.578697  24.430000
# ...                ...        ...        ...         ...        ...
# 2023-12-22  286.511536  18.930000  46.820000  220.921875  20.950001
# 2023-12-26  287.650879  18.610001  47.549999  221.745544  20.350000
# 2023-12-27  289.310822  18.540001  47.160000  222.727997  20.379999
# 2023-12-28  290.577911  18.670000  47.820000  222.370758  20.469999
# 2023-12-29  291.235992  18.540001  46.880001  223.789825  20.040001
#
# Ticker             DPZ         BKNG        MGM         RCL         HLT  \
# Date
# ...

# %%
loader.load_data(dt.datetime(2024,11,1),dtype='cov') #load cov matrix, betas or returns by need
# Out:
# Ticker       FOX       NOW      AMCR       JPM        KO      ABBV      CPAY  \
# Ticker
# FOX     0.038603 -0.004767  0.014809  0.013288  0.004943  0.004702  0.015084
# NOW    -0.004767  0.109455  0.000923  0.004692  0.001103  0.008231  0.010750
# AMCR    0.014809  0.000923  0.048648  0.010236  0.008158  0.007507  0.014304
# JPM     0.013288  0.004692  0.010236  0.037774  0.004103  0.007606  0.014905
# KO      0.004943  0.001103  0.008158  0.004103  0.014829  0.008843  0.005308
# ...          ...       ...       ...       ...       ...       ...       ...
# NWSA    0.015111  0.012438  0.011430  0.013508  0.001238  0.002754  0.006683
# CCI     0.013818 -0.002410  0.022089  0.006451  0.010837  0.009685  0.006931
# APTV    0.026037  0.015768  0.024766  0.024800  0.006635  0.001400  0.027745
# LVS     0.017710  0.009922  0.013445  0.011746  0.002767  0.006206  0.013330
# MOH    -0.003158  0.036982  0.002963  0.002226  0.012139  0.017500 -0.011743
#
# ...
